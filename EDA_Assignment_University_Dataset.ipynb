# %% [markdown]
# <a href="https://colab.research.google.com/github/gawankarsanket/dswithchirag_assignments/blob/main/EDA_Assignment_University_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Universities.csv")

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#top 5 rows
df.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
#last 5 rows
df.tail()
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
#dataset diamension rowXcol
df.shape
# Out:
# (25, 7)

# %%
#total elements  (25*7)
df.size
# Out:
# 175

# %%
df.dtypes
# Out:
# Univ        object
# SAT          int64
# Top10        int64
# Accept       int64
# SFRatio      int64
# Expenses     int64
# GradRate     int64
# dtype: object

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df.mean() #mean for all numberic columns
# Out:
# <ipython-input-16-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# SAT          1266.44
# Top10          76.48
# Accept         39.20
# SFRatio        12.72
# Expenses    27388.00
# GradRate       86.72
# dtype: float64

# %%
df['SAT'].mean()   #mean for specified col
# Out:
# 1266.44

# %%
df.max()  #max for all cols
# Out:
# Univ         Yale
# SAT          1415
# Top10         100
# Accept         90
# SFRatio        25
# Expenses    63575
# GradRate       97
# dtype: object

# %%
df[['Accept','Expenses']].max()   #max for specified cols
# Out:
# Accept         90
# Expenses    63575
# dtype: int64

# %%
df.head(1)
# Out:
#     Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0  Brown  1310     89      22       13     22704        94

# %%
# display all row, and first 3 cols only

df.iloc[:,0:3]
# Out:
#             Univ   SAT  Top10
# 0          Brown  1310     89
# 1        CalTech  1415    100
# 2            CMU  1260     62
# 3       Columbia  1310     76
# 4        Cornell  1280     83
# 5      Dartmouth  1340     89
# 6           Duke  1315     90
# 7     Georgetown  1255     74
# 8        Harvard  1400     91
# 9   JohnsHopkins  1305     75
# 10           MIT  1380     94
# 11  Northwestern  1260     85
# 12     NotreDame  1255     81
# 13     PennState  1081     38
# 14     Princeton  1375     91
# 15        Purdue  1005     28
# 16      Stanford  1360     90
# 17      TexasA&M  1075     49
# 18    UCBerkeley  1240     95
# 19      UChicago  1290     75
# 20     UMichigan  1180     65
# 21         UPenn  1285     80
# 22           UVA  1225     77
# 23    UWisconsin  1085     40
# 24          Yale  1375     95

# %%
#rows 1 to 3 last 3 columns and

# %%
df.iloc[1:4,-3:]
# Out:
#    SFRatio  Expenses  GradRate
# 1        6     63575        81
# 2        9     25026        72
# 3       12     31510        88

# %%
#Sort   (by default ascending= True)
df.sort_values('GradRate',ascending=False)[['Univ','Expenses','GradRate']]
# Out:
#             Univ  Expenses  GradRate
# 8        Harvard     39525        97
# 24          Yale     43514        96
# 5      Dartmouth     32162        95
# 14     Princeton     30220        95
# 6           Duke     31585        95
# 0          Brown     22704        94
# 12     NotreDame     15122        94
# 16      Stanford     36450        93
# 7     Georgetown     20126        92
# 22           UVA     13349        92
# 10           MIT     34870        91
# 21         UPenn     27553        90
# 4        Cornell     21864        90
# 11  Northwestern     28052        89
# 3       Columbia     31510        88
# 19      UChicago     38380        87
# 9   JohnsHopkins     58691        87
# 20     UMichigan     15470        85
# 1        CalTech     63575        81
# 13     PennState     10185        80
# 18    UCBerkeley     15140        78
# 2            CMU     25026        72
# 23    UWisconsin     11857        71
# 15        Purdue      9066        69
# ...

# %%
#Groupby GradRate and show avg expenses and SAT score

df.groupby('GradRate')[['SAT','Expenses']].mean()
# Out:
#                   SAT      Expenses
# GradRate
# 67        1075.000000   8704.000000
# 69        1005.000000   9066.000000
# 71        1085.000000  11857.000000
# 72        1260.000000  25026.000000
# 78        1240.000000  15140.000000
# 80        1081.000000  10185.000000
# 81        1415.000000  63575.000000
# 85        1180.000000  15470.000000
# 87        1297.500000  48535.500000
# 88        1310.000000  31510.000000
# 89        1260.000000  28052.000000
# 90        1282.500000  24708.500000
# 91        1380.000000  34870.000000
# 92        1240.000000  16737.500000
# 93        1360.000000  36450.000000
# 94        1282.500000  18913.000000
# 95        1343.333333  31322.333333
# 96        1375.000000  43514.000000
# 97        1400.000000  39525.000000

# %%
#Filter
df['GradRate']>90
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24     True
# Name: GradRate, dtype: bool

# %%
#filter and sorting together
df[df['GradRate']>90].sort_values('GradRate')
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 10         MIT  1380     94      30       10     34870        91
# 7   Georgetown  1255     74      24       12     20126        92
# 22         UVA  1225     77      44       14     13349        92
# 16    Stanford  1360     90      20       12     36450        93
# 0        Brown  1310     89      22       13     22704        94
# 12   NotreDame  1255     81      42       13     15122        94
# 5    Dartmouth  1340     89      23       10     32162        95
# 6         Duke  1315     90      30       12     31585        95
# 14   Princeton  1375     91      14        8     30220        95
# 24        Yale  1375     95      19       11     43514        96
# 8      Harvard  1400     91      14       11     39525        97
