# %% [markdown]
# <a href="https://colab.research.google.com/github/gawankarsanket/dswithchirag_assignments/blob/main/EDA_Assignment_Healthexp_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Reading CSV file into dataframe

# %%
df=pd.read_csv("/content/healthexp.csv")

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
#Total Cells rowsxcolumn
df.size
# Out:
# 1096

# %%
#number of rows and columns
df.shape
# Out:
# (274, 4)

# %%
df.dtypes
# Out:
# Year                 int64
# Country             object
# Spending_USD       float64
# Life_Expectancy    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Spending_USD', 'Life_Expectancy'], dtype='object')

# %%
df.values
# Out:
# array([[1970, 'Germany', 252.311, 70.6],
#        [1970, 'France', 192.143, 72.2],
#        [1970, 'Great Britain', 123.993, 71.9],
#        ...,
#        [2020, 'Great Britain', 5018.7, 80.4],
#        [2020, 'Japan', 4665.641, 84.7],
#        [2020, 'USA', 11859.179, 77.0]], dtype=object)

# %%
df.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
df['Country'].unique()
# Out:
# array(['Germany', 'France', 'Great Britain', 'Japan', 'USA', 'Canada'],
#       dtype=object)

# %%
df[["Country","Spending_USD"]]
# Out:
#            Country  Spending_USD
# 0          Germany       252.311
# 1           France       192.143
# 2    Great Britain       123.993
# 3            Japan       150.437
# 4              USA       326.961
# ..             ...           ...
# 269        Germany      6938.983
# 270         France      5468.418
# 271  Great Britain      5018.700
# 272          Japan      4665.641
# 273            USA     11859.179
#
# [274 rows x 2 columns]

# %%
df_country=df.groupby("Country")

# %%
df_country[['Spending_USD']].mean()
# Out:
#                Spending_USD
# Country
# Canada          2685.778341
# France          3045.145057
# Germany         2667.280200
# Great Britain   2034.192465
# Japan           1860.257902
# USA             4388.570529

# %% [markdown]
# ##Year wise life expetency trend

# %%
df.groupby('Year')[['Life_Expectancy']].mean()
# Out:
#       Life_Expectancy
# Year
# 1970        71.520000
# 1971        71.920000
# 1972        71.800000
# 1973        72.033333
# 1974        72.400000
# 1975        72.850000
# 1976        73.325000
# 1977        73.700000
# 1978        73.866667
# 1979        74.500000
# 1980        74.233333
# 1981        74.620000
# 1982        74.920000
# 1983        75.120000
# 1984        75.420000
# 1985        75.616667
# 1986        75.860000
# 1987        76.180000
# 1988        76.260000
# 1989        76.480000
# 1990        76.916667
# 1991        77.060000
# 1992        77.100000
# 1993        77.083333
# 1994        77.450000
# 1995        77.450000
# 1996        77.766667
# 1997        78.066667
# 1998        78.283333
# 1999        78.383333
# 2000        78.716667
# 2001        78.950000
# 2002        79.083333
# 2003        79.133333
# 2004        79.683333
# 2005        79.766667
# 2006        80.150000
# 2007        80.366667
# 2008        80.483333
# 2009        80.766667
# ...

# %%
df.groupby("Year")[['Year','Life_Expectancy']].describe()
# Out:
#       Year                                                       \
#      count    mean  std     min     25%     50%     75%     max
# Year
# 1970   5.0  1970.0  0.0  1970.0  1970.0  1970.0  1970.0  1970.0
# 1971   5.0  1971.0  0.0  1971.0  1971.0  1971.0  1971.0  1971.0
# 1972   3.0  1972.0  0.0  1972.0  1972.0  1972.0  1972.0  1972.0
# 1973   3.0  1973.0  0.0  1973.0  1973.0  1973.0  1973.0  1973.0
# 1974   3.0  1974.0  0.0  1974.0  1974.0  1974.0  1974.0  1974.0
# 1975   4.0  1975.0  0.0  1975.0  1975.0  1975.0  1975.0  1975.0
# 1976   4.0  1976.0  0.0  1976.0  1976.0  1976.0  1976.0  1976.0
# 1977   3.0  1977.0  0.0  1977.0  1977.0  1977.0  1977.0  1977.0
# 1978   3.0  1978.0  0.0  1978.0  1978.0  1978.0  1978.0  1978.0
# 1979   4.0  1979.0  0.0  1979.0  1979.0  1979.0  1979.0  1979.0
# 1980   6.0  1980.0  0.0  1980.0  1980.0  1980.0  1980.0  1980.0
# 1981   5.0  1981.0  0.0  1981.0  1981.0  1981.0  1981.0  1981.0
# 1982   5.0  1982.0  0.0  1982.0  1982.0  1982.0  1982.0  1982.0
# ...

# %% [markdown]
# ###country wise life expetency trend

# %%
df.groupby("Country")[['Year','Life_Expectancy']].mean()
# Out:
#                       Year  Life_Expectancy
# Country
# Canada         1998.318182        78.706818
# France         2001.857143        79.565714
# Germany        1995.080000        76.726000
# Great Britain  1998.627907        77.620930
# Japan          1995.000000        79.554902
# USA            1995.000000        75.843137

# %%
df.groupby("Country")[['Life_Expectancy']].describe()
# Out:
#               Life_Expectancy                                           \
#                         count       mean       std   min     25%   50%
# Country
# Canada                   44.0  78.706818  2.502222  72.8  76.775  78.7
# France                   35.0  79.565714  2.862120  72.2  78.050  79.4
# Germany                  50.0  76.726000  3.473915  70.6  73.575  77.1
# Great Britain            43.0  77.620930  2.827548  71.9  75.350  77.5
# Japan                    51.0  79.554902  3.547242  72.0  76.950  79.8
# USA                      51.0  75.843137  2.336258  70.9  74.550  75.7
#
#
#                   75%   max
# Country
# Canada         80.975  82.2
# France         82.200  82.9
# Germany        80.175  81.3
# Great Britain  80.400  81.4
# Japan          82.650  84.7
# USA            77.950  78.9
