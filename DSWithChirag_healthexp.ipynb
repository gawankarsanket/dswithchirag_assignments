# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading CSV file into dataframe

# %%
df=pd.read_csv("/content/healthexp.csv")

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
#Total Cells rowsxcolumn
df.size
# Out:
# 1096

# %%
#number of rows and columns
df.shape
# Out:
# (274, 4)

# %%
df.dtypes
# Out:
# Year                 int64
# Country             object
# Spending_USD       float64
# Life_Expectancy    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Spending_USD', 'Life_Expectancy'], dtype='object')

# %%
df.values
# Out:
# array([[1970, 'Germany', 252.311, 70.6],
#        [1970, 'France', 192.143, 72.2],
#        [1970, 'Great Britain', 123.993, 71.9],
#        ...,
#        [2020, 'Great Britain', 5018.7, 80.4],
#        [2020, 'Japan', 4665.641, 84.7],
#        [2020, 'USA', 11859.179, 77.0]], dtype=object)

# %%
df.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
df['Country'].unique()
# Out:
# array(['Germany', 'France', 'Great Britain', 'Japan', 'USA', 'Canada'],
#       dtype=object)

# %%
df[["Country","Spending_USD"]]
# Out:
#            Country  Spending_USD
# 0          Germany       252.311
# 1           France       192.143
# 2    Great Britain       123.993
# 3            Japan       150.437
# 4              USA       326.961
# ..             ...           ...
# 269        Germany      6938.983
# 270         France      5468.418
# 271  Great Britain      5018.700
# 272          Japan      4665.641
# 273            USA     11859.179
#
# [274 rows x 2 columns]

# %%
df_country=df.groupby("Country")

# %%
df_country.describe()
# Out:
#                Year                                                            \
#               count         mean        std     min      25%     50%      75%
# Country
# Canada         44.0  1998.318182  13.183451  1971.0  1987.75  1998.5  2009.25
# France         35.0  2001.857143  12.466763  1970.0  1994.50  2003.0  2011.50
# Germany        50.0  1995.080000  15.005904  1970.0  1982.25  1995.5  2007.75
# Great Britain  43.0  1998.627907  13.273718  1970.0  1988.50  1999.0  2009.50
# Japan          51.0  1995.000000  14.866069  1970.0  1982.50  1995.0  2007.50
# USA            51.0  1995.000000  14.866069  1970.0  1982.50  1995.0  2007.50
#
#                       Spending_USD               ...                         \
#                   max        count         mean  ...         75%        max
# Country                                          ...
# Canada         2020.0         44.0  2685.778341  ...  3998.28700   5828.324
# ...

# %% [markdown]
# ##Year wise life expetency trend

# %%
df[['Year','Life_Expectancy']].groupby("Year")

# %%
df[['Year','Life_Expectancy']].groupby("Year").describe()
# Out:
#      Life_Expectancy
#                count       mean       std   min     25%    50%     75%   max
# Year
# 1970             5.0  71.520000  0.719027  70.6  70.900  71.90  72.000  72.2
# 1971             5.0  71.920000  0.936483  70.8  71.200  71.90  72.800  72.9
# 1972             3.0  71.800000  1.216553  71.0  71.100  71.20  72.200  73.2
# 1973             3.0  72.033333  1.184624  71.3  71.350  71.40  72.400  73.4
# 1974             3.0  72.400000  1.153256  71.5  71.750  72.00  72.850  73.7
# 1975             4.0  72.850000  1.190238  71.4  72.375  72.85  73.325  74.3
# 1976             4.0  73.325000  1.278997  71.8  72.625  73.35  74.050  74.8
# 1977             3.0  73.700000  1.442221  72.5  72.900  73.30  74.300  75.3
# 1978             3.0  73.866667  1.680278  72.4  72.950  73.50  74.600  75.7
# 1979             4.0  74.500000  1.471960  72.8  73.625  74.50  75.375  76.2
# 1980             6.0  74.233333  1.229092  72.9  73.325  74.00  74.975  76.1
# ...

# %% [markdown]
# ###country wise life expetency trend

# %%
df[['Country','Life_Expectancy']].groupby("Country")

# %%
df[['Country','Life_Expectancy']].groupby("Country").describe()
# Out:
#               Life_Expectancy                                           \
#                         count       mean       std   min     25%   50%
# Country
# Canada                   44.0  78.706818  2.502222  72.8  76.775  78.7
# France                   35.0  79.565714  2.862120  72.2  78.050  79.4
# Germany                  50.0  76.726000  3.473915  70.6  73.575  77.1
# Great Britain            43.0  77.620930  2.827548  71.9  75.350  77.5
# Japan                    51.0  79.554902  3.547242  72.0  76.950  79.8
# USA                      51.0  75.843137  2.336258  70.9  74.550  75.7
#
#
#                   75%   max
# Country
# Canada         80.975  82.2
# France         82.200  82.9
# Germany        80.175  81.3
# Great Britain  80.400  81.4
# Japan          82.650  84.7
# USA            77.950  78.9
