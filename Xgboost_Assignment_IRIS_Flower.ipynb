# %% [markdown]
# <a href="https://colab.research.google.com/github/gawankarsanket/dswithchirag_assignments/blob/main/Xgboost_Assignment_IRIS_Flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IRIS FLOWER CLASSIFICATION
#
# ## Iris is a flowering plan, which is having 3 identical species Setosa, versicolor and virginica.
# ## By appearene they look exactly similar however they are distiguishable based on their physical attributes of Sepal and Petal, lenght and width.
#
#
# ## This dataset contains the these attributes and classification of species.
#
# ## Our objective is train  a ML model using this dataset as training set and prepare the same to identify the flower based on specs.
#
# ## will try to build model of  DT, RF and XGB and find the best accurate model.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Out Target variable is 'species'. It is in categorical form. We must use label encoder to convert it into numeric.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Check for missing value if any

# %%
df.isnull().sum()


#  NO missing values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ### Check the data count for each output category, so as to decide if dataset is balanced or not.

# %%
df['species'].value_counts()

#Equal distribution of each category. Meaning datsaset is balance.
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# ###Lets perform Lable encoding for target variable in order to convert it into numbers

# %%
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()
df['species'] = LE.fit_transform(df['species'])

df['species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ## Divide in X and Y and then train test split

# %%
# Now divide them into x and y
# x will have all input column and y will have output column

#df.loc[startRow : EndRow , StartCol: end Col] , [:, : ] ie. all row all column

x=df.iloc[:,0:4]
y=df.iloc[:,4:]

# %%
y.head()
# Out:
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.35, random_state=42)

xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((97, 4), (53, 4), (97, 1), (53, 1))

# %% [markdown]
# ## We will try to build DT , RF and XGboost and see the performance

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score

def evaluate_model (model,xtrain,ytrain,xtest,ytest):
  report={}
  model.fit(xtrain, ytrain)
  preds=model.predict(xtest)
  model_score = accuracy_score(ytest,preds)
  best_parameter=model.best_params_


  return preds,model_score,best_parameter

# %%
from sklearn.model_selection import RandomizedSearchCV

classifier_RF=RandomForestClassifier()

## Hypeparameter Tuning for RandomForest
params_RF={'max_depth':[3,5,10,None],
        'n_estimators':[100,200,300],
        'criterion':['gini','entropy'],
        'oob_score':[True]
           }

model_RF=RandomizedSearchCV(classifier_RF,param_distributions=params_RF,scoring='accuracy',cv=3,verbose=2)

RF,RF_score,RF_best_parameter=evaluate_model(model_RF,xtrain,ytrain,xtest,ytest)

RF,RF_score*100,RF_best_parameter
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV] END criterion=gini, max_depth=3, n_estimators=300, oob_score=True; total time=   0.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV] END criterion=gini, max_depth=3, n_estimators=300, oob_score=True; total time=   0.5s
# ...

# %%
from sklearn.model_selection import GridSearchCV

classifier_DT=DecisionTreeClassifier()

## Hypeparameter Tuning for DT
params_DT={'max_depth':[3,5,10,None],
           'criterion':['gini','entropy']
           }


model_DT=GridSearchCV(classifier_DT,param_grid=params_DT,scoring='accuracy',cv=5,verbose=3)

DT,DT_score,DT_best_parameter=evaluate_model(model_DT,xtrain,ytrain,xtest,ytest)

DT,DT_score*100,DT_best_parameter
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END .......criterion=gini, max_depth=3;, score=1.000 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=3;, score=0.750 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=3;, score=1.000 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=3;, score=1.000 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=3;, score=0.947 total time=   0.0s
# [CV 1/5] END .......criterion=gini, max_depth=5;, score=0.850 total time=   0.0s
# [CV 2/5] END .......criterion=gini, max_depth=5;, score=0.750 total time=   0.0s
# [CV 3/5] END .......criterion=gini, max_depth=5;, score=1.000 total time=   0.0s
# [CV 4/5] END .......criterion=gini, max_depth=5;, score=1.000 total time=   0.0s
# [CV 5/5] END .......criterion=gini, max_depth=5;, score=0.947 total time=   0.0s
# [CV 1/5] END ......criterion=gini, max_depth=10;, score=0.950 total time=   0.0s
# ...

# %%
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

classifier_xgb=XGBClassifier()


## Hypeparameter Tuning for XGB
param_xgb= {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    #'subsample': [0.8, 1.0],
    #'colsample_bytree': [0.8, 1.0],
    'gamma': [0, 0.1, 0.2],
    }

model_xgb=RandomizedSearchCV(classifier_xgb,param_distributions=param_xgb,scoring='accuracy',cv=5,verbose=3)

xgb,xgb_score,xgb_best_parameter=evaluate_model(model_xgb,xtrain,ytrain,xtest,ytest)

xgb,xgb_score*100, xgb_best_parameter
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.950 total time=   0.1s
# [CV 2/5] END gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.700 total time=   0.1s
# [CV 3/5] END gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.947 total time=   0.1s
# [CV 4/5] END gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.947 total time=   0.1s
# [CV 5/5] END gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.947 total time=   0.1s
# [CV 1/5] END gamma=0.2, learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.950 total time=   0.1s
# [CV 2/5] END gamma=0.2, learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.700 total time=   0.1s
# [CV 3/5] END gamma=0.2, learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.947 total time=   0.1s
# ...

# %%
DT_best_parameter,DT_score
# Out:
# ({'criterion': 'gini', 'max_depth': 3}, 0.9811320754716981)

# %%
RF_best_parameter,RF_score
# Out:
# ({'oob_score': True, 'n_estimators': 300, 'max_depth': 3, 'criterion': 'gini'},
#  0.9811320754716981)

# %%
xgb_best_parameter,xgb_score
# Out:
# ({'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0.2},
#  0.9811320754716981)

# %% [markdown]
# ## PREDCITED TEST DATASET

# %%
xtest['Actual_Species']=ytest
xtest['Predicted_DT']=DT
xtest['Predicted_RF']=RF
xtest['Predicted_XGB']=xgb

# %%
xtest.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Actual_Species  \
# 73            6.1          2.8           4.7          1.2               1
# 18            5.7          3.8           1.7          0.3               0
# 118           7.7          2.6           6.9          2.3               2
# 78            6.0          2.9           4.5          1.5               1
# 76            6.8          2.8           4.8          1.4               1
#
#      Predicted_DT  Predicted_RF  Predicted_XGB
# 73              1             1              1
# 18              0             0              0
# 118             2             2              2
# 78              1             1              1
# 76              1             1              1

# %% [markdown]
# ## inverse transform from Numeric to actual categories

# %%
xtest['Actual_Species']=LE.inverse_transform(xtest['Actual_Species'])
xtest['Predicted_DT']=LE.inverse_transform(xtest['Predicted_DT'])
xtest['Predicted_RF']=LE.inverse_transform(xtest['Predicted_RF'])
xtest['Predicted_XGB']=LE.inverse_transform(xtest['Predicted_XGB'])

# %%
xtest.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width Actual_Species  \
# 73            6.1          2.8           4.7          1.2     versicolor
# 18            5.7          3.8           1.7          0.3         setosa
# 118           7.7          2.6           6.9          2.3      virginica
# 78            6.0          2.9           4.5          1.5     versicolor
# 76            6.8          2.8           4.8          1.4     versicolor
#
#     Predicted_DT Predicted_RF Predicted_XGB
# 73    versicolor   versicolor    versicolor
# 18        setosa       setosa        setosa
# 118    virginica    virginica     virginica
# 78    versicolor   versicolor    versicolor
# 76    versicolor   versicolor    versicolor

# %% [markdown]
# ## CROSSTAB check for DT

# %%
pd.crosstab(xtest['Actual_Species'],xtest['Predicted_DT'])
# Out:
# Predicted_DT    setosa  versicolor  virginica
# Actual_Species
# setosa              19           0          0
# versicolor           0          17          0
# virginica            0           1         16

# %% [markdown]
# ## CROSSTAB check for RF

# %%
pd.crosstab(xtest['Actual_Species'],xtest['Predicted_RF'])
# Out:
# Predicted_RF    setosa  versicolor  virginica
# Actual_Species
# setosa              19           0          0
# versicolor           0          17          0
# virginica            0           1         16

# %% [markdown]
# ## CROSSTAB check for XGB

# %%
pd.crosstab(xtest['Actual_Species'],xtest['Predicted_XGB'])
# Out:
# Predicted_XGB   setosa  versicolor  virginica
# Actual_Species
# setosa              19           0          0
# versicolor           0          17          0
# virginica            0           1         16
